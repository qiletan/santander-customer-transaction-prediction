# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import lightgbm as lgb
import os
import shutil
import matplotlib.pyplot as plt
import seaborn as sns
#import pandas_profiling

# %%
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:100].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    #plt.savefig('lgbm_importances01.png')

# %%
train_df = pd.read_csv('../data/train.csv')
test_df = pd.read_csv('../data/test.csv')

# %% [markdown]
# ## FE

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
var_list = [f for f in train_df.columns if 'var' in f]
mean_var_list = [f+'_over_minmax' for f in train_df.columns if 'var' in f]

# train_df['mean'] = np.mean(train_df[var_list],axis=1)
# train_df['std'] = np.std(train_df[var_list],axis=1)
# train_df['min'] = np.min(train_df[var_list],axis=1)
# train_df['max'] = np.max(train_df[var_list],axis=1)
# train_df['sum'] = np.sum(train_df[var_list],axis=1)
# train_df['median'] = np.median(train_df[var_list],axis=1)

train_df[mean_var_list] = train_df[var_list]/((np.max(train_df[var_list],axis=0)-np.min(train_df[var_list],axis=0)))
test_df[mean_var_list] = test_df[var_list]/((np.max(test_df[var_list],axis=0)-np.min(test_df[var_list],axis=0)))

# %%
test_df.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8  ...  var_190_over_minmax  var_191_over_minmax  \
# 0  18.2675  2.1337  ...            -0.062568             0.619630
# 1  18.6316 -4.4131  ...             0.308151             0.461992
# 2  20.2537  1.5233  ...            -0.021723             0.574869
# 3  20.5660  3.3755  ...             0.277781             0.474631
# 4  10.6048  2.9890  ...             0.122659             0.479635
#
#    var_192_over_minmax  var_193_over_minmax  var_194_over_minmax  \
# 0            -0.126037             0.084377             0.738551
# 1             0.082876             0.348699             0.839025
# 2             0.174539             0.075054             0.699235
# 3             0.146132             0.123299             0.818066
# 4             0.113125             0.116293             1.053283
#
#    var_195_over_minmax  var_196_over_minmax  var_197_over_minmax  \
# 0             0.260846             0.146172             1.755593
# 1             0.050469            -0.049731             1.616619
# 2             0.225022            -0.238025             1.156497
# 3             0.334726             0.132487             1.511497
# 4            -0.030241            -0.172818             1.193574
#
#    var_198_over_minmax  var_199_over_minmax
# 0             0.775378            -0.129439
# 1             0.958651            -0.311377
# 2             0.997053            -0.344086
# 3             0.652327            -0.062507
# 4             0.697891            -0.136340
#
# [5 rows x 401 columns]

# %% [markdown]
# ## Model

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

n_folds = 5
random_seed = 26
model = 'lgb_over_minmax'


model_name = "{0}_{1}_folds".format(model, n_folds)
print("Model: {}".format(model_name))
# Out:
# Model: lgb_over_minmax_5_folds

# %%
feats = train_df.iloc[:,2:].columns.tolist();feats
# Out:
# ['var_0',
#  'var_1',
#  'var_2',
#  'var_3',
#  'var_4',
#  'var_5',
#  'var_6',
#  'var_7',
#  'var_8',
#  'var_9',
#  'var_10',
#  'var_11',
#  'var_12',
#  'var_13',
#  'var_14',
#  'var_15',
#  'var_16',
#  'var_17',
#  'var_18',
#  'var_19',
#  'var_20',
#  'var_21',
#  'var_22',
#  'var_23',
#  'var_24',
#  'var_25',
#  'var_26',
#  'var_27',
#  'var_28',
#  'var_29',
#  'var_30',
#  'var_31',
#  'var_32',
#  'var_33',
#  'var_34',
#  'var_35',
#  'var_36',
#  'var_37',
#  'var_38',
#  'var_39',
#  'var_40',
#  'var_41',
#  'var_42',
#  'var_43',
#  'var_44',
#  'var_45',
#  'var_46',
#  'var_47',
#  'var_48',
#  'var_49',
#  'var_50',
#  'var_51',
#  'var_52',
#  'var_53',
#  'var_54',
#  'var_55',
#  'var_56',
#  'var_57',
#  'var_58',
#  'var_59',
#  'var_60',
#  'var_61',
#  'var_62',
#  'var_63',
#  'var_64',
#  'var_65',
#  'var_66',
#  'var_67',
#  'var_68',
#  'var_69',
#  'var_70',
#  'var_71',
#  'var_72',
#  'var_73',
#  'var_74',
#  'var_75',
#  'var_76',
#  'var_77',
#  'var_78',
#  'var_79',
#  'var_80',
#  'var_81',
#  'var_82',
#  'var_83',
#  'var_84',
#  'var_85',
#  'var_86',
#  'var_87',
#  'var_88',
#  'var_89',
#  'var_90',
#  'var_91',
#  'var_92',
#  'var_93',
#  'var_94',
#  'var_95',
#  'var_96',
#  'var_97',
#  'var_98',
#  'var_99',
#  'var_100',
#  'var_101',
#  'var_102',
#  'var_103',
#  'var_104',
#  'var_105',
#  'var_106',
#  'var_107',
#  'var_108',
#  'var_109',
#  'var_110',
#  'var_111',
#  'var_112',
#  'var_113',
#  'var_114',
#  'var_115',
#  'var_116',
#  'var_117',
#  'var_118',
#  'var_119',
#  'var_120',
#  'var_121',
#  'var_122',
#  'var_123',
#  'var_124',
#  'var_125',
#  'var_126',
#  'var_127',
#  'var_128',
#  'var_129',
#  'var_130',
#  'var_131',
#  'var_132',
#  'var_133',
#  'var_134',
#  'var_135',
#  'var_136',
#  'var_137',
#  'var_138',
#  'var_139',
#  'var_140',
#  'var_141',
#  'var_142',
#  'var_143',
#  'var_144',
#  'var_145',
#  'var_146',
#  'var_147',
#  'var_148',
#  'var_149',
#  'var_150',
#  'var_151',
#  'var_152',
#  'var_153',
#  'var_154',
#  'var_155',
#  'var_156',
#  'var_157',
#  'var_158',
#  'var_159',
#  'var_160',
#  'var_161',
#  'var_162',
#  'var_163',
#  'var_164',
#  'var_165',
#  'var_166',
#  'var_167',
#  'var_168',
#  'var_169',
#  'var_170',
#  'var_171',
#  'var_172',
#  'var_173',
#  'var_174',
#  'var_175',
#  'var_176',
#  'var_177',
#  'var_178',
#  'var_179',
#  'var_180',
#  'var_181',
#  'var_182',
#  'var_183',
#  'var_184',
#  'var_185',
#  'var_186',
#  'var_187',
#  'var_188',
#  'var_189',
#  'var_190',
#  'var_191',
#  'var_192',
#  'var_193',
#  'var_194',
#  'var_195',
#  'var_196',
#  'var_197',
#  'var_198',
#  'var_199',
#  'var_0_over_minmax',
#  'var_1_over_minmax',
#  'var_2_over_minmax',
#  'var_3_over_minmax',
#  'var_4_over_minmax',
#  'var_5_over_minmax',
#  'var_6_over_minmax',
#  'var_7_over_minmax',
#  'var_8_over_minmax',
#  'var_9_over_minmax',
#  'var_10_over_minmax',
#  'var_11_over_minmax',
#  'var_12_over_minmax',
#  'var_13_over_minmax',
#  'var_14_over_minmax',
#  'var_15_over_minmax',
#  'var_16_over_minmax',
#  'var_17_over_minmax',
#  'var_18_over_minmax',
#  'var_19_over_minmax',
#  'var_20_over_minmax',
#  'var_21_over_minmax',
#  'var_22_over_minmax',
#  'var_23_over_minmax',
#  'var_24_over_minmax',
#  'var_25_over_minmax',
#  'var_26_over_minmax',
#  'var_27_over_minmax',
#  'var_28_over_minmax',
#  'var_29_over_minmax',
#  'var_30_over_minmax',
#  'var_31_over_minmax',
#  'var_32_over_minmax',
#  'var_33_over_minmax',
#  'var_34_over_minmax',
#  'var_35_over_minmax',
#  'var_36_over_minmax',
#  'var_37_over_minmax',
#  'var_38_over_minmax',
#  'var_39_over_minmax',
#  'var_40_over_minmax',
#  'var_41_over_minmax',
#  'var_42_over_minmax',
#  'var_43_over_minmax',
#  'var_44_over_minmax',
#  'var_45_over_minmax',
#  'var_46_over_minmax',
#  'var_47_over_minmax',
#  'var_48_over_minmax',
#  'var_49_over_minmax',
#  'var_50_over_minmax',
#  'var_51_over_minmax',
#  'var_52_over_minmax',
#  'var_53_over_minmax',
#  'var_54_over_minmax',
#  'var_55_over_minmax',
#  'var_56_over_minmax',
#  'var_57_over_minmax',
#  'var_58_over_minmax',
#  'var_59_over_minmax',
#  'var_60_over_minmax',
#  'var_61_over_minmax',
#  'var_62_over_minmax',
#  'var_63_over_minmax',
#  'var_64_over_minmax',
#  'var_65_over_minmax',
#  'var_66_over_minmax',
#  'var_67_over_minmax',
#  'var_68_over_minmax',
#  'var_69_over_minmax',
#  'var_70_over_minmax',
#  'var_71_over_minmax',
#  'var_72_over_minmax',
#  'var_73_over_minmax',
#  'var_74_over_minmax',
#  'var_75_over_minmax',
#  'var_76_over_minmax',
#  'var_77_over_minmax',
#  'var_78_over_minmax',
#  'var_79_over_minmax',
#  'var_80_over_minmax',
#  'var_81_over_minmax',
#  'var_82_over_minmax',
#  'var_83_over_minmax',
#  'var_84_over_minmax',
#  'var_85_over_minmax',
#  'var_86_over_minmax',
#  'var_87_over_minmax',
#  'var_88_over_minmax',
#  'var_89_over_minmax',
#  'var_90_over_minmax',
#  'var_91_over_minmax',
#  'var_92_over_minmax',
#  'var_93_over_minmax',
#  'var_94_over_minmax',
#  'var_95_over_minmax',
#  'var_96_over_minmax',
#  'var_97_over_minmax',
#  'var_98_over_minmax',
#  'var_99_over_minmax',
#  'var_100_over_minmax',
#  'var_101_over_minmax',
#  'var_102_over_minmax',
#  'var_103_over_minmax',
#  'var_104_over_minmax',
#  'var_105_over_minmax',
#  'var_106_over_minmax',
#  'var_107_over_minmax',
#  'var_108_over_minmax',
#  'var_109_over_minmax',
#  'var_110_over_minmax',
#  'var_111_over_minmax',
#  'var_112_over_minmax',
#  'var_113_over_minmax',
#  'var_114_over_minmax',
#  'var_115_over_minmax',
#  'var_116_over_minmax',
#  'var_117_over_minmax',
#  'var_118_over_minmax',
#  'var_119_over_minmax',
#  'var_120_over_minmax',
#  'var_121_over_minmax',
#  'var_122_over_minmax',
#  'var_123_over_minmax',
#  'var_124_over_minmax',
#  'var_125_over_minmax',
#  'var_126_over_minmax',
#  'var_127_over_minmax',
#  'var_128_over_minmax',
#  'var_129_over_minmax',
#  'var_130_over_minmax',
#  'var_131_over_minmax',
#  'var_132_over_minmax',
#  'var_133_over_minmax',
#  'var_134_over_minmax',
#  'var_135_over_minmax',
#  'var_136_over_minmax',
#  'var_137_over_minmax',
#  'var_138_over_minmax',
#  'var_139_over_minmax',
#  'var_140_over_minmax',
#  'var_141_over_minmax',
#  'var_142_over_minmax',
#  'var_143_over_minmax',
#  'var_144_over_minmax',
#  'var_145_over_minmax',
#  'var_146_over_minmax',
#  'var_147_over_minmax',
#  'var_148_over_minmax',
#  'var_149_over_minmax',
#  'var_150_over_minmax',
#  'var_151_over_minmax',
#  'var_152_over_minmax',
#  'var_153_over_minmax',
#  'var_154_over_minmax',
#  'var_155_over_minmax',
#  'var_156_over_minmax',
#  'var_157_over_minmax',
#  'var_158_over_minmax',
#  'var_159_over_minmax',
#  'var_160_over_minmax',
#  'var_161_over_minmax',
#  'var_162_over_minmax',
#  'var_163_over_minmax',
#  'var_164_over_minmax',
#  'var_165_over_minmax',
#  'var_166_over_minmax',
#  'var_167_over_minmax',
#  'var_168_over_minmax',
#  'var_169_over_minmax',
#  'var_170_over_minmax',
#  'var_171_over_minmax',
#  'var_172_over_minmax',
#  'var_173_over_minmax',
#  'var_174_over_minmax',
#  'var_175_over_minmax',
#  'var_176_over_minmax',
#  'var_177_over_minmax',
#  'var_178_over_minmax',
#  'var_179_over_minmax',
#  'var_180_over_minmax',
#  'var_181_over_minmax',
#  'var_182_over_minmax',
#  'var_183_over_minmax',
#  'var_184_over_minmax',
#  'var_185_over_minmax',
#  'var_186_over_minmax',
#  'var_187_over_minmax',
#  'var_188_over_minmax',
#  'var_189_over_minmax',
#  'var_190_over_minmax',
#  'var_191_over_minmax',
#  'var_192_over_minmax',
#  'var_193_over_minmax',
#  'var_194_over_minmax',
#  'var_195_over_minmax',
#  'var_196_over_minmax',
#  'var_197_over_minmax',
#  'var_198_over_minmax',
#  'var_199_over_minmax']

# %%
clfs = []
folds = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=random_seed)
oof_preds = np.zeros((len(train_df), 1))
test_preds = np.zeros((len(test_df), 1))


X = train_df[feats]
y = train_df['target']
X_test = test_df[feats]
test_ids = test_df.ID_code.values


parameters = {
    'objective': 'binary',
    'metric': 'auc',
    'is_unbalance': 'true',
    #'scale_pos_weight': 400,
    #'device' : 'gpu' ,
    'boosting': 'gbdt',
    'num_leaves': 31, #31
    'feature_fraction': 0.5,
    'bagging_fraction': 0.7,
    'bagging_freq': 10,
    'learning_rate': 0.05, #0.05
    'verbose': 30
    #'min_data_in_leaf': 200
}

feature_importance_df = pd.DataFrame()
for fold_, (trn_, val_) in enumerate(folds.split(X, y)):
    print("Current Fold: {}".format(fold_+1))
    trn_x, trn_y = X.iloc[trn_, :], y[trn_]
    val_x, val_y = X.iloc[val_, :], y[val_]


    trn_lgb = lgb.Dataset(trn_x, trn_y)
    val_lgb = lgb.Dataset(val_x, val_y)
    clf = lgb.train(parameters,
                     train_set=trn_lgb,
                     #valid_sets=[valid_data_lgb,holdout_data_lgb],
                     valid_sets=[trn_lgb, val_lgb],
                     num_boost_round=3000,
                     early_stopping_rounds=50,
                     verbose_eval=500)
    


    val_pred = clf.predict(val_x)
    test_fold_pred = clf.predict(X_test)

    print("AUC = {}".format(roc_auc_score(val_y, val_pred)))
    oof_preds[val_, :] = val_pred.reshape((-1, 1))
    test_preds += test_fold_pred.reshape((-1, 1))
    
    print('getting feature importance')
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = feats
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    
test_preds /= n_folds
roc_score = roc_auc_score(y, oof_preds.ravel())
print("Overall AUC = {}".format(roc_score))


print("Saving submission file")
sample = pd.read_csv('../data/sample_submission.csv')
sample.target = test_preds.astype(float)
sample.ID_code = test_ids
sample.to_csv('../submissions/{}_{}.csv'.format(model_name,str(roc_score)), index=False)

display_importances(feature_importance_df)
# Out:
# Current Fold: 1
# Training until validation scores don't improve for 50 rounds.
# [500]	training's auc: 0.964483	valid_1's auc: 0.888831
# Early stopping, best iteration is:
# [757]	training's auc: 0.978693	valid_1's auc: 0.891125
# AUC = 0.8911254986566293
# getting feature importance
# Current Fold: 2
# Training until validation scores don't improve for 50 rounds.
# [500]	training's auc: 0.964744	valid_1's auc: 0.88724
# Early stopping, best iteration is:
# [835]	training's auc: 0.982136	valid_1's auc: 0.889309
# AUC = 0.8893091032981613
# getting feature importance
# Current Fold: 3
# Training until validation scores don't improve for 50 rounds.
# [500]	training's auc: 0.964117	valid_1's auc: 0.893265
# Early stopping, best iteration is:
# [687]	training's auc: 0.975251	valid_1's auc: 0.89504
# AUC = 0.8950401204096251
# getting feature importance
# Current Fold: 4
# Training until validation scores don't improve for 50 rounds.
# [500]	training's auc: 0.96474	valid_1's auc: 0.89266
# Early stopping, best iteration is:
# [681]	training's auc: 0.975218	valid_1's auc: 0.894943
# AUC = 0.8949425816587442
# getting feature importance
# Current Fold: 5
# Training until validation scores don't improve for 50 rounds.
# [500]	training's auc: 0.964548	valid_1's auc: 0.890047
# Early stopping, best iteration is:
# [706]	training's auc: 0.976192	valid_1's auc: 0.891552
# AUC = 0.8915518643309207
# getting feature importance
# Overall AUC = 0.8922354519839368
# Saving submission file

# %%
# %%javascript
# var nb = IPython.notebook;
# var kernel = IPython.notebook.kernel;
# var command = "NOTEBOOK_FULL_PATH = '" + nb.base_url + nb.notebook_path + "'";
# kernel.execute(command);

# %%
shutil.copyfile(os.path.basename(NOTEBOOK_FULL_PATH), 
                             '../models/{}_{}.ipynb'.format(model_name, str(roc_score)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3eee34b4b9a0> in <module>
#       1
#       2
# ----> 3 shutil.copyfile(os.path.basename(NOTEBOOK_FULL_PATH),
#       4                              '../models/{}_{}.ipynb'.format(model_name, str(roc_score)))
#
# NameError: name 'NOTEBOOK_FULL_PATH' is not defined
